# %% [markdown]
# ## Ch 01. 데이터

# %% [markdown]
# ### 1. 데이터

# %%
import pandas as pd

# %%
pd.read_csv('data/ch1_sport_test.csv')
# Out:
#    학생번호  학년    악력  윗몸일으키기  점수  순위
# 0     1   1  40.2      34  15   4
# 1     2   1  34.2      14   7  10
# 2     3   1  28.8      27  11   7
# 3     4   2  39.0      27  14   5
# 4     5   2  50.9      32  17   2
# 5     6   2  36.5      20   9   9
# 6     7   3  36.6      31  13   6
# 7     8   3  49.2      37  18   1
# 8     9   3  26.0      28  10   8
# 9    10   3  47.4      32  16   3

# %%
# 학생번호를 인덱스로 하여 csv 파일 읽어들이기
df = pd.read_csv('data/ch1_sport_test.csv', index_col='학생번호')
df
# Out:
#       학년    악력  윗몸일으키기  점수  순위
# 학생번호
# 1      1  40.2      34  15   4
# 2      1  34.2      14   7  10
# 3      1  28.8      27  11   7
# 4      2  39.0      27  14   5
# 5      2  50.9      32  17   2
# 6      2  36.5      20   9   9
# 7      3  36.6      31  13   6
# 8      3  49.2      37  18   1
# 9      3  26.0      28  10   8
# 10     3  47.4      32  16   3

# %%
df['악력']
# Out:
# 학생번호
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 악력, dtype: float64

# %% [markdown]
# ## 2. 데이터의 크기

# %%
# 데이터 프레임 크기 구하기
df.shape
# 데이터 개수(레코드 수)가 10, 변수 개수(컬럼 수)가 5
# Out:
# (10, 5)
